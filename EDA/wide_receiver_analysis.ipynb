# %% [markdown]
# # Exploratory Data Analysis- NFL Success

# %% [markdown]
# ---
# ## Imports

# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
rs = np.random.RandomState(8)
sns.set(color_codes=True)
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Introduction
# Data analysis on the WR and FB/RB positions to find relation between data and Pro Bowls

# %% [markdown]
# ## Loading Data
# All data was pulled from the github project

# %%
df = pd.read_csv("C:/Users/matth/Documents/GitHub/NFL_Success/final_df.csv")
positions = ['TE', 'QB']
df = df[~df.Pos.isin(positions)]
df.drop('Rnd', axis=1, inplace=True)
df.to_csv('my_analysis.csv')
full_df = pd.read_csv('my_analysis.csv')
wr_df = full_df[full_df['Pos'] == 'WR']
fr_df = full_df[full_df['Pos'] != 'WR']

# %%
wr_df[0:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1                 Player Pos       School   Wt  \
# 0           0             0  J.J. Arcega-Whiteside  WR     Stanford  225
# 2           2             2           Miles Boykin  WR   Notre Dame  220
# 3           3             3             A.J. Brown  WR  Mississippi  226
# 4           4             4         Marquise Brown  WR     Oklahoma  166
# 5           5             5        Parris Campbell  WR   Ohio State  205
#
#    40yd  Vertical  Bench  Broad Jump  ...  PassTD  Int RushAtt  RushYds  \
# 0   NaN       NaN    NaN         NaN  ...     NaN  NaN     NaN      NaN
# 2  4.42      43.5   12.0       140.0  ...     NaN  NaN     NaN      NaN
# 3  4.49      36.5   19.0       120.0  ...     NaN  NaN     3.0     60.0
# 4   NaN       NaN    NaN         NaN  ...     NaN  NaN     NaN      NaN
# 5  4.31      40.0   11.0       135.0  ...     NaN  NaN     4.0     34.0
#
#    RushTD  RecRec  RecYds  RecTD  Ht Ft  Ht In
# 0     NaN    10.0   169.0    1.0      6      2
# 2     NaN    13.0   198.0    3.0      6      4
# 3     1.0    52.0  1051.0    8.0      6      0
# 4     NaN    46.0   584.0    7.0      5      9
# 5     0.0    18.0   127.0    1.0      6      0
#
# [5 rows x 51 columns]

# %%
fr_df[0:5]
# Out:
#     Unnamed: 0  Unnamed: 0.1             Player Pos          School   Wt  \
# 1            1             1   Ryquell Armstead  RB          Temple  220
# 7            9             9       Myles Gaskin  RB      Washington  205
# 10          14            14      Damien Harris  RB         Alabama  216
# 12          17            17  Darrell Henderson  RB         Memphis  208
# 13          18            18       Justice Hill  RB  Oklahoma State  198
#
#     40yd  Vertical  Bench  Broad Jump  ...  PassTD  Int RushAtt  RushYds  \
# 1   4.45      30.0   22.0       114.0  ...     NaN  NaN    35.0    108.0
# 7   4.58      35.5   24.0       118.0  ...     NaN  NaN    36.0    133.0
# 10  4.57      37.0   16.0       121.0  ...     NaN  NaN     4.0     12.0
# 12  4.49      33.5   22.0       121.0  ...     NaN  NaN    39.0    147.0
# 13  4.40      40.0   21.0       130.0  ...     NaN  NaN    58.0    225.0
#
#     RushTD  RecRec  RecYds  RecTD  Ht Ft  Ht In
# 1      0.0    14.0   144.0    2.0      5     11
# 7      1.0     7.0    51.0    0.0      5      9
# 10     0.0     NaN     NaN    NaN      5     10
# 12     0.0     4.0    37.0    0.0      5      8
# 13     2.0     8.0    70.0    0.0      5     10
#
# [5 rows x 51 columns]

# %% [markdown]
# ## WR Analysis
# ---

# %% [markdown]
# ### Heat Map for College Stats

# %%
hm = wr_df[['PB','C Games','C Rec', 'C RecYds', 'C  RecAvg', 'C RecTD', 'C ScrimPLays', 'C ScrimYds','C ScrimAvg',
            'C ScrimTD']]
plt.figure(figsize=(10,7))
cmap = sns.diverging_palette(255, 12, as_cmap=True)
g = sns.heatmap(hm.corr(), annot=True, cmap=cmap)
g.set_title('Heat map for College Stats')
# Out:
# Text(0.5, 1.0, 'Heat map for College Stats')

# %% [markdown]
# ### Heat Map for Combine Stats

# %%
hm = wr_df[['PB','Round','Wt', '40yd', 'Vertical', 'Broad Jump', '3Cone', 'Shuttle','Pick', 'Year']]
plt.figure(figsize=(10,7))
cmap = sns.diverging_palette(255, 12, as_cmap=True)
g = sns.heatmap(hm.corr(), annot=True, cmap=cmap)
g.set_title('Heat map for Combine Stats')
# Out:
# Text(0.5, 1.0, 'Heat map for Combine Stats')

# %% [markdown]
# ### Number of Pro Bowls based on round drafted

# %%
g = sns.barplot(x='Round', y='PB', data=wr_df, palette='bright')
g.set_title('PB per round')
# Out:
# Text(0.5, 1.0, 'PB per round')

# %% [markdown]
# ### Number of Pro Bowls based on weight at combine and round drafted

# %%
wr_df['Weight above average'] = wr_df['Wt'] > wr_df['Wt'].mean()

g = sns.barplot(x='Round', y='PB', hue='Weight above average', data=wr_df, palette='bright')
g.set_title('PB per round by weight')
plt.show()

# %% [markdown]
# ### Number of Pro Bowls based on 40yd times at combine and round drafted

# %%
wr_df['40yd time above average'] = wr_df['40yd'] < wr_df['40yd'].mean()
g = sns.barplot(x='Round', y='PB', hue='40yd time above average', data=wr_df, palette='bright')
g.set_title('PB per round by average 40yd time')
# Out:
# Text(0.5, 1.0, 'PB per round by average 40yd time')

# %% [markdown]
# ### Number of Pro Bowls based on vertical height at combine and round drafted

# %%
wr_df['Vertical height above average'] = wr_df['Vertical'] > wr_df['Vertical'].mean()
g = sns.barplot(x='Round', y='PB', hue='Vertical height above average', data=wr_df, palette='bright')
g.set_title('PB per round by average Vertical')
# Out:
# Text(0.5, 1.0, 'PB per round by average Vertical')

# %% [markdown]
# ### Number of Pro Bowls based on number of college receiving touchdowns

# %%
g = sns.barplot(x='C RecTD', y='PB', data=wr_df, palette='bright')
for label in g.get_xticklabels()[::2]:
     label.set_visible(False)
g.set_title('PB by College Receiving TD')
# Out:
# Text(0.5, 1.0, 'PB by College Receiving TD')

# %% [markdown]
# ### Number of Pro Bowls based on amount of receiving yards in college

# %%
g = sns.barplot(x='C ScrimTD', y='PB', data=wr_df, palette='bright')
for label in g.get_xticklabels()[::2]:
     label.set_visible(False)
g.set_title('PB by College Scrimmage TD')
# Out:
# Text(0.5, 1.0, 'PB by College Scrimmage TD')

# %% [markdown]
# ### Number of Pro Bowls based on number of college receiving touchdowns and average number of college scrimmage touchdowns

# %%
wr_df['College Scrim TD above average'] = wr_df['C ScrimTD'] > wr_df['C ScrimTD'].mean()
g = sns.lineplot(x='C RecTD', y='PB', hue='College Scrim TD above average', data=wr_df, palette='bright')
g.set_title('PB by College Receiving TD')
# Out:
# Text(0.5, 1.0, 'PB by College Receiving TD')

# %% [markdown]
# ## FB/RB Analysis
# ---

# %% [markdown]
# ### Number of Pro Bowls based on round drafted

# %%
g = sns.barplot(x='Round', y='PB', data=fr_df, palette='bright')
g.set_title('PB per round')
# Out:
# Text(0.5, 1.0, 'PB per round')

# %% [markdown]
# ### Number of Pro Bowls based on bench reps at combine and round drafted

# %%
fr_df['Bench Reps above average'] = fr_df['Bench'] > fr_df['Bench'].mean()
g = sns.barplot(x='Round', y='PB', hue='Bench Reps above average', data=fr_df, palette='bright')
g.set_title('PB per round by bench')
# Out:
# Text(0.5, 1.0, 'PB per round by bench')

# %% [markdown]
# ### Number of Pro Bowls based on 40yd time at combine and round drafted

# %%
fr_df['40yd time quicker than average'] = fr_df['40yd'] < fr_df['40yd'].mean()
g = sns.barplot(x='Round', y='PB', hue='40yd time quicker than average', data=fr_df, palette='bright')
g.set_title('PB per round by average 40yd time')
# Out:
# Text(0.5, 1.0, 'PB per round by average 40yd time')

# %% [markdown]
# ### Number of Pro Bowls based on round drafted

# %%
g = sns.barplot(x='Round', y='PB', data=fr_df, palette='bright')
g.set_title('PB per round')
# Out:
# Text(0.5, 1.0, 'PB per round')

# %% [markdown]
# ### Number of Pro Bowls based on bench reps at combine and round drafted

# %%
fr_df['Bench Reps above average'] = fr_df['Bench'] > fr_df['Bench'].mean()
g = sns.barplot(x='Round', y='PB', hue='Bench Reps above average', data=fr_df, palette='bright')
g.set_title('PB per round by bench')
# Out:
# Text(0.5, 1.0, 'PB per round by bench')

# %% [markdown]
# ### Number of Pro Bowls based on vertical height at combine and round drafted

# %%
fr_df['Vertical height above average'] = fr_df['Vertical'] > fr_df['Vertical'].mean()
g = sns.barplot(x='Round', y='PB', hue='Vertical height above average', data=fr_df, palette='bright')
g.set_title('PB per round by average vertical')
# Out:
# Text(0.5, 1.0, 'PB per round by average vertical')

# %% [markdown]
# ### Number of Pro Bowls based on number of college rushing touchdowns

# %%
g = sns.barplot(x='C RushTD', y='PB', data=fr_df, palette='bright')
for label in g.get_xticklabels()[::2]:
     label.set_visible(False)
for label in g.get_xticklabels()[::2]:
     label.set_visible(False)
g.set_title('PB by College Scrim TD')
# Out:
# Text(0.5, 1.0, 'PB by College Scrim TD')

# %% [markdown]
# ### Number of Pro Bowls based on number of college scrimmage touchdowns

# %%
g = sns.barplot(x='C ScrimTD', y='PB', data=fr_df, palette='bright')
for label in g.get_xticklabels()[::2]:
     label.set_visible(False)
for label in g.get_xticklabels()[::2]:
     label.set_visible(False)
g.set_title('PB by College Scrim TD')
plt.show()

# %% [markdown]
# ### Number of Pro Bowls based on number of college rushing touchdowns and average college scrimmage touchdowns

# %%
fr_df['College Scrimmage Touchdowns above average'] = fr_df['C ScrimTD'] > fr_df['C ScrimTD'].mean()
g = sns.lineplot(x='C RushTD', y='PB', hue='College Scrimmage Touchdowns above average', data=fr_df, palette='bright')
g.set_title('PB by College Rush TD and average Scrim TD')
plt.show()

# %% [markdown]
# ## Models
# ---

# %% [markdown]
# ### WR
# Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
y = wr_df['PB'] > 0
features = ['Round', '40yd', 'Wt', 'Vertical', 'C ScrimTD', 'C RecTD']
X = wr_df[features].fillna(0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print()
# Out:
# [[85 17]
#  [ 7  5]]
