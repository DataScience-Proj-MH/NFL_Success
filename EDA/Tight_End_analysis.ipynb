# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

all_players_df = pd.read_csv('final_df.csv')
del all_players_df['Unnamed: 0']

all_players_df.head()
# Out:
#                 Player_x Pos_x       School   Wt  40yd  Vertical  Bench  \
# 0  J.J. Arcega-Whiteside    WR     Stanford  225   NaN       NaN    NaN
# 1       Ryquell Armstead    RB       Temple  220  4.45      30.0   22.0
# 2           Miles Boykin    WR   Notre Dame  220  4.42      43.5   12.0
# 3             A.J. Brown    WR  Mississippi  226  4.49      36.5   19.0
# 4         Marquise Brown    WR     Oklahoma  166   NaN       NaN    NaN
#
#    Broad Jump  3Cone  Shuttle  ... PassTD  Int  RushAtt  RushYds  RushTD  \
# 0         NaN    NaN      NaN  ...    NaN  NaN      NaN      NaN     NaN
# 1       114.0   7.02     4.29  ...    NaN  NaN     35.0    108.0     0.0
# 2       140.0   6.77     4.07  ...    NaN  NaN      NaN      NaN     NaN
# 3       120.0    NaN      NaN  ...    NaN  NaN      3.0     60.0     1.0
# 4         NaN    NaN      NaN  ...    NaN  NaN      NaN      NaN     NaN
#
#    RecRec  RecYds  RecTD  Ht Ft  Ht In
# 0    10.0   169.0    1.0      6      2
# ...

# %%
te_df = all_players_df[all_players_df['Pos_x'] == 'TE']
te_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 6 to 1197
# Data columns (total 59 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player_x      214 non-null    object
#  1   Pos_x         214 non-null    object
#  2   School        214 non-null    object
#  3   Wt            214 non-null    int64
#  4   40yd          207 non-null    float64
#  5   Vertical      167 non-null    float64
#  6   Bench         168 non-null    float64
#  7   Broad Jump    163 non-null    float64
#  8   3Cone         146 non-null    float64
#  9   Shuttle       147 non-null    float64
#  10  Team          214 non-null    object
#  11  Round         214 non-null    int64
#  12  Pick          214 non-null    int64
#  13  Year          214 non-null    int64
#  14  C Games       214 non-null    int64
#  15  C Rec         214 non-null    int64
#  16  C RecYds      214 non-null    int64
#  17  C  RecAvg     214 non-null    float64
# ...

# %%
te_df.describe()
# Out:
#                Wt        40yd    Vertical       Bench  Broad Jump       3Cone  \
# count  214.000000  207.000000  167.000000  168.000000  163.000000  146.000000
# mean   254.186916    4.736184   33.604790   20.988095  116.134969    7.142260
# std      8.920232    0.133604    3.188284    4.474797    5.882088    0.212008
# min    225.000000    4.370000   26.500000    3.000000  102.000000    6.720000
# 25%    249.000000    4.650000   31.500000   18.000000  112.000000    6.990000
# 50%    254.000000    4.750000   33.500000   21.000000  115.000000    7.120000
# 75%    260.000000    4.830000   35.500000   24.000000  119.500000    7.310000
# max    275.000000    5.060000   43.500000   35.000000  134.000000    7.650000
#
#           Shuttle       Round        Pick         Year  ...    PassTD  \
# count  147.000000  214.000000  214.000000   214.000000  ...  8.000000
# mean     4.331088    3.906542  116.771028  2009.626168  ...  0.125000
# ...

# %%
te_college_df= te_df[['PB' , '40yd' , 'Vertical' ,  'Bench' , 'Broad Jump' , '3Cone' , 'Shuttle' , 'Round' , 'Pick' , 'Year']]
te_college_df.describe()
# Out:
#                PB        40yd    Vertical       Bench  Broad Jump       3Cone  \
# count  214.000000  207.000000  167.000000  168.000000  163.000000  146.000000
# mean     0.350467    4.736184   33.604790   20.988095  116.134969    7.142260
# std      1.148003    0.133604    3.188284    4.474797    5.882088    0.212008
# min      0.000000    4.370000   26.500000    3.000000  102.000000    6.720000
# 25%      0.000000    4.650000   31.500000   18.000000  112.000000    6.990000
# 50%      0.000000    4.750000   33.500000   21.000000  115.000000    7.120000
# 75%      0.000000    4.830000   35.500000   24.000000  119.500000    7.310000
# max     11.000000    5.060000   43.500000   35.000000  134.000000    7.650000
#
#           Shuttle       Round        Pick         Year
# count  147.000000  214.000000  214.000000   214.000000
# mean     4.331088    3.906542  116.771028  2009.626168
# std      0.152639    1.881627   67.837204     5.720441
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
te_college_df['made PB'] = te_df['PB'] > 0
te_college_df

sns.set(style="whitegrid", palette="deep", color_codes=True)
g = sns.violinplot(x='Round' , y='Bench' , hue='made PB' , split=True, data=te_college_df)
plt.ylabel('Bench Reps')

plt.show()

# %%
sns.boxplot(x='PB' , y='40yd' , data=te_college_df ,whis=[4.3,5.2] , palette='vlag')
plt.show()

# %%
#draft_with_pb = quarterback_df.loc[quarterback_df['Year'] < 2012]
te_df['made PB'] = te_df['PB'] > 0
draft_with_pb = te_df[['made PB','Round','Wt', '40yd', 'Vertical', 'Broad Jump', '3Cone', 'Shuttle','Pick', 'Year']]


plt.figure(figsize=(10,7))
sns.heatmap(draft_with_pb.corr(), annot=True)
plt.show()

# %%
draft_with_pb = te_df[['Round','C Games','C Rec', 'C RecYds', 'C  RecAvg', 'C RecTD', 'C ScrimPLays', 'C ScrimYds','C ScrimAvg', 'C ScrimTD']]

plt.figure(figsize=(10,7))
sns.heatmap(draft_with_pb.corr(), annot=True)
plt.show()

# %%
# C ScrimYds C ScrimTD C RecTD C RecYds Rnd Pick 40yd vertical

# %%
# Code you have previously used to load data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm , neighbors


#te_df = te_df.loc[te_df['Year'] < 2012]
te_df = all_players_df[all_players_df['Pos_x'] == 'WR']

y =te_df['Round']
features = ['C Games','C Rec', 'C RecYds', 'C  RecAvg', 'C RecTD', 'C ScrimPLays', 'C ScrimYds','C ScrimAvg', 'C ScrimTD','Wt', '40yd', 'Vertical', 'Broad Jump', '3Cone', 'Shuttle','Pick', 'Year']
X = te_df[features].fillna(0)

# Split into validation and training data
train_X, val_X, train_y, val_y = train_test_split(X, y,test_size=.3, random_state=4323334)
te_model = neighbors.KNeighborsClassifier()

# fit your model
te_model.fit(train_X, train_y)
#print confidence
confidence = te_model.score(val_X , val_y)
print(confidence)
y_predict = te_model.predict(val_X)
print(y_predict)
# Out:
# 0.20437956204379562
# [1 1 4 2 5 2 1 1 2 4 3 3 2 3 2 5 3 3 1 4 3 7 1 1 6 5 2 1 3 2 2 5 2 2 3 6 4
#  1 2 2 5 1 4 4 2 3 6 3 1 2 3 2 3 4 6 6 3 3 4 4 3 2 6 3 1 5 2 3 2 2 4 2 5 1
#  4 3 5 5 2 3 1 6 1 6 5 3 3 3 5 4 5 2 6 2 7 5 6 2 4 2 2 4 5 5 4 2 5 2 5 2 4
#  6 5 2 4 3 4 5 2 4 1 6 1 2 3 6 4 4 2 6 2 1 2 3 6 1 2]
